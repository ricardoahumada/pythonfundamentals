# %%
# Wirh kernel Azure ML
import sys, os

module_path = os.path.realpath('/home/azureuser/cloudfiles/code/Users/ricardo_devtestops/workspace/pythonfundamentals/local')

if module_path not in sys.path:
    sys.path.append(module_path)

from my_module.functions import hola

hola()
# Out:
# hola module!!

# %%
# With Kernel Entornos de Python > 3.9.5

import os

print(os.getcwd())

from my_module.functions import hola

hola()
# Out:
# d:\Shared\MyTrainingRepos\pythonfundamentals\local
# hola module!!
