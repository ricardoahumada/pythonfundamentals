# %%
import my_sql_module as msm

PGHOST = '...'
PGDATABASE = '...'
PGUSER = '...'
PGPASSWORD = '..'

# %%
# Una conexión para todo el programa
conn = msm.create_server_connection(PGHOST, PGDATABASE, PGUSER, PGPASSWORD)
# Out:
# Database conn successful

# %%
def pagos_mayores_a(valor):

    cur = None

    data = None

    SQL = 'SELECT * FROM payments WHERE amount > ' + str(valor)
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        data = cur.fetchall()
    except Exception as err:
        print(f"Error: '{err}'")
    finally:
        if cur:
            cur.close()

    return data


resultado = pagos_mayores_a(100)
print(resultado)
# Out:
# SQL: SELECT * FROM payments WHERE amount > 100
# [(103, 'HQ336336', datetime.date(2004, 10, 19), Decimal('6066.78')), (103, 'JM555205', datetime.date(2003, 6, 5), Decimal('14571.44')), (103, 'OM314933', datetime.date(2004, 12, 18), Decimal('1676.14')), (112, 'BO864823', datetime.date(2004, 12, 17), Decimal('14191.12')), (112, 'HQ55022', datetime.date(2003, 6, 6), Decimal('32641.98')), (112, 'ND748579', datetime.date(2004, 8, 20), Decimal('33347.88')), (114, 'GG31455', datetime.date(2003, 5, 20), Decimal('45864.03')), (114, 'MA765515', datetime.date(2004, 12, 15), Decimal('82261.22')), (114, 'NP603840', datetime.date(2003, 5, 31), Decimal('7565.08')), (114, 'NR27552', datetime.date(2004, 3, 10), Decimal('44894.74')), (119, 'DB933704', datetime.date(2004, 11, 14), Decimal('19501.82')), (119, 'LN373447', datetime.date(2004, 8, 8), Decimal('47924.19')), (119, 'NG94694', datetime.date(2005, 2, 22), Decimal('49523.67')), (121, 'DB889831', datetime.date(2003, 2, 16), Decimal('50218.95')), (121, 'FD317790', datetime.date(2003, 10, 28), Decimal('1491.38')), (121, 'KI831359', datetime.date(2004, 11, 4), Decimal('17876.32')), (121, 'MA302151', datetime.date(2004, 11, 28), Decimal('34638.14')), (124, 'AE215433', datetime.date(2005, 3, 5), Decimal('101244.59')), (124, 'BG255406', datetime.date(2004, 8, 28), Decimal('85410.87')), (124, 'CQ287967', datetime.date(2003, 4, 11), Decimal('11044.30')), (124, 'ET64396', datetime.date(2005, 4, 16), Decimal('83598.04')), (124, 'HI366474', datetime.date(2004, 12, 27), Decimal('47142.70')), (124, 'HR86578', datetime.date(2004, 11, 2), Decimal('55639.66')), (124, 'KI131716', datetime.date(2003, 8, 15), Decimal('111654.40')), (124, 'LF217299', datetime.date(2004, 3, 26), Decimal('43369.30')), (124, 'NT141748', datetime.date(2003, 11, 25), Decimal('45084.38')), (128, 'DI925118', datetime.date(2003, 1, 28), Decimal('10549.01')), (128, 'FA465482', datetime.date(2003, 10, 18), Decimal('24101.81')), (128, 'FH668230', datetime.date(2004, 3, 24), Decimal('33820.62')), (128, 'IP383901', datetime.date(2004, 11, 18), Decimal('7466.32')), (129, 'DM826140', datetime.date(2004, 12, 8), Decimal('26248.78')), (129, 'ID449593', datetime.date(2003, 12, 11), Decimal('23923.93')), (129, 'PI42991', datetime.date(2003, 4, 9), Decimal('16537.85')), (131, 'CL442705', datetime.date(2003, 3, 12), Decimal('22292.62')), (131, 'MA724562', datetime.date(2004, 12, 2), Decimal('50025.35')), (131, 'NB445135', datetime.date(2004, 9, 11), Decimal('35321.97')), (141, 'AU364101', datetime.date(2003, 7, 19), Decimal('36251.03')), (141, 'DB583216', datetime.date(2004, 11, 1), Decimal('36140.38')), (141, 'DL460618', datetime.date(2005, 5, 19), Decimal('46895.48')), (141, 'HJ32686', datetime.date(2004, 1, 30), Decimal('59830.55')), (141, 'ID10962', datetime.date(2004, 12, 31), Decimal('116208.40')), (141, 'IN446258', datetime.date(2005, 3, 25), Decimal('65071.26')), (141, 'JE105477', datetime.date(2005, 3, 18), Decimal('120166.58')), (141, 'JN355280', datetime.date(2003, 10, 26), Decimal('49539.37')), (141, 'JN722010', datetime.date(2003, 2, 25), Decimal('40206.20')), (141, 'KT52578', datetime.date(2003, 12, 9), Decimal('63843.55')), (141, 'MC46946', datetime.date(2004, 7, 9), Decimal('35420.74')), (141, 'MF629602', datetime.date(2004, 8, 16), Decimal('20009.53')), (141, 'NU627706', datetime.date(2004, 5, 17), Decimal('26155.91')), (144, 'IR846303', datetime.date(2004, 12, 12), Decimal('36005.71')), (144, 'LA685678', datetime.date(2003, 4, 9), Decimal('7674.94')), (145, 'CN328545', datetime.date(2004, 7, 3), Decimal('4710.73')), (145, 'ED39322', datetime.date(2004, 4, 26), Decimal('28211.70')), (145, 'HR182688', datetime.date(2004, 12, 1), Decimal('20564.86')), (145, 'JJ246391', datetime.date(2003, 2, 20), Decimal('53959.21')), (146, 'FP549817', datetime.date(2004, 3, 18), Decimal('40978.53')), (146, 'FU793410', datetime.date(2004, 1, 16), Decimal('49614.72')), (146, 'LJ160635', datetime.date(2003, 12, 10), Decimal('39712.10')), (151, 'BF686658', datetime.date(2003, 12, 22), Decimal('58793. ...

# %%
def pagos_mayores_y_cliente(valor, customer):

    cur = None

    data = None

    SQL = 'SELECT * FROM payments WHERE amount > ' + str(valor) + ' AND customerNumber = '+ str(customer)
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        data = cur.fetchall()

    except Exception as err:
        print(f"Error: '{err}'")
    finally:
        if cur:
            cur.close()

    return data


resultado = pagos_mayores_y_cliente(100, 103)
print(resultado)
# Out:
# SQL: SELECT * FROM payments WHERE amount > 100 AND customerNumber = 103
# [(103, 'HQ336336', datetime.date(2004, 10, 19), Decimal('6066.78')), (103, 'JM555205', datetime.date(2003, 6, 5), Decimal('14571.44')), (103, 'OM314933', datetime.date(2004, 12, 18), Decimal('1676.14'))]

# %%
def clientes_nombre_comiencen_o_terminen(texto):

    cur = None

    data = None

    SQL = "SELECT * FROM customers WHERE LOWER(customerName) LIKE '{0}%' OR LOWER(customerName) LIKE '%{0}'".format(texto)
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        data = cur.fetchall()

    except Exception as err:
        print(f"Error: '{err}'")
    finally:
        if cur:
            cur.close()
        

    return data


resultado = clientes_nombre_comiencen_o_terminen('a')
print(resultado)
# Out:
# SQL: SELECT * FROM customers WHERE LOWER(customerName) LIKE 'a%' OR LOWER(customerName) LIKE '%a'
# [(103, 'Atelier graphique', 'Carine  Schmitt', '40.32.2555', '54, rue Royale', 'Nantes', None, '44000', 'France', 1370, Decimal('21000.00')), (114, 'Australian Collectors, Co.', 'Peter Ferguson', '03 9520 4555', '636 St Kilda Road, Level 3', 'Melbourne', 'Victoria', '3004', 'Australia', 1611, Decimal('117300.00')), (168, 'American Souvenirs Inc', 'Keith Franco', '2035557845', '149 Spinnaker Dr., Suite 101', 'New Haven', 'CT', '97823', 'USA', 1286, Decimal('0.00')), (187, 'AV Stores, Co.', 'Rachel Ashworth', '(171) 555-1555', 'Fauntleroy Circus', 'Manchester', None, 'EC2 5NT', 'UK', 1501, Decimal('136800.00')), (198, 'Auto-Moto Classics Inc.', 'Leslie Taylor', '6175558428', '16780 Pompton St.', 'Brickhaven', 'MA', '58339', 'USA', 1216, Decimal('23000.00')), (206, 'Asian Shopping Network, Co', 'Brydey Walker', '+612 9411 1555', 'Suntec Tower Three, 8 Temasek', 'Singapore', None, '038988', 'Singapore', None, Decimal('0.00')), (237, 'ANG Resellers', 'Alejandra  Camino', '(91) 745 6555', 'Gran Vía, 1', 'Madrid', None, '28001', 'Spain', None, Decimal('0.00')), (242, 'Alpha Cognac', 'Annette  Roulet', '61.77.6555', '1 rue Alsace-Lorraine', 'Toulouse', None, '31000', 'France', 1370, Decimal('61100.00')), (249, 'Amica Models & Co.', 'Paolo  Accorti', '011-4988555', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', 1401, Decimal('113000.00')), (256, 'Auto Associés & Cie.', 'Daniel  Tonini', '30.59.8555', '67, avenue de lEurope', 'Versailles', None, '78000', 'France', 1370, Decimal('77900.00')), (276, 'Annas Decorations, Ltd', 'Anna OHara', '02 9936 8555', '201 Miller Street, Level 15', 'North Sydney', 'NSW', '2060', 'Australia', 1611, Decimal('107800.00')), (333, 'Australian Gift Network, Co', 'Ben Calaghan', '61-7-3844-6555', '31 Duncan St. West End', 'South Brisbane', 'Queensland', '4101', 'Australia', 1611, Decimal('51600.00')), (348, 'Asian Treasures, Inc.', 'Patricia  McKenna', '2967 555', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', None, Decimal('0.00')), (406, 'Auto Canal+ Petit', 'Dominique Perrier', '(1) 47.55.6555', '25, rue Lauriston', 'Paris', None, '75016', 'France', 1337, Decimal('95000.00')), (465, 'Anton Designs, Ltd.', 'Carmen Anton', '+34 913 728555', 'c/ Gobelas, 19-1 Urb. La Florida', 'Madrid', None, '28023', 'Spain', None, Decimal('0.00')), (471, 'Australian Collectables, Ltd', 'Sean Clenahan', '61-9-3844-6555', '7 Allen Street', 'Glen Waverly', 'Victoria', '3150', 'Australia', 1611, Decimal('60300.00'))]

# %%
def actualiza_codigo_postal_para_ciudad(new_cp, city):

    cur = None

    isOK = False

    SQL = "UPDATE customers SET postalcode = {0} WHERE LOWER(city) LIKE '%{1}%'".format(
        new_cp, city)
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        conn.commit()
        isOK = True
    except Exception as err:
        print(f"Error: '{err}'")
        if conn:
            conn.rollback()
    finally:
        if cur:
            cur.close()

    return isOK


resultado = actualiza_codigo_postal_para_ciudad(10005, 'las')
print(resultado)
# Out:
# SQL: UPDATE customers SET postalcode = 10005 WHERE LOWER(city) LIKE '%las%'
# True

# %%
def show_data_for_fields(campos, valor):

    cur = None

    data = None

    SQL = "SELECT {0} FROM sales WHERE sales_amount>={1} ORDER BY sales_amount ASC".format(','.join(campos), valor)
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        data = cur.fetchall()
    except Exception as err:
        print(f"Error: '{err}'")
    finally:
        if cur:
            cur.close()
        

    return data


lcampos = ('orderNumber', 'status', 'sales_amount')
resultado = show_data_for_fields(lcampos, 100)
print(resultado)
# Out:
# SQL: SELECT orderNumber,status,sales_amount FROM sales WHERE sales_amount>=100 ORDER BY sales_amount ASC
# [(10419, 'Shipped', Decimal('481.50')), (10420, 'In Process', Decimal('529.35')), (10322, 'Shipped', Decimal('531.00')), (10407, 'On Hold', Decimal('546.66')), (10425, 'In Process', Decimal('553.52')), (10344, 'Shipped', Decimal('557.60')), (10110, 'Shipped', Decimal('577.60')), (10280, 'Shipped', Decimal('597.40')), (10409, 'Shipped', Decimal('625.50')), (10214, 'Shipped', Decimal('643.80')), (10239, 'Shipped', Decimal('649.40')), (10219, 'Shipped', Decimal('653.52')), (10418, 'Shipped', Decimal('662.90')), (10304, 'Shipped', Decimal('671.83')), (10141, 'Shipped', Decimal('675.78')), (10281, 'Shipped', Decimal('679.00')), (10367, 'Resolved', Decimal('679.42')), (10135, 'Shipped', Decimal('687.20')), (10114, 'Shipped', Decimal('687.36')), (10203, 'Shipped', Decimal('697.83')), (10138, 'Shipped', Decimal('730.18')), (10264, 'Shipped', Decimal('780.40')), (10254, 'Shipped', Decimal('796.00')), (10124, 'Shipped', Decimal('798.38')), (10182, 'Shipped', Decimal('802.24')), (10147, 'Shipped', Decimal('830.75')), (10400, 'Shipped', Decimal('834.20')), (10370, 'Shipped', Decimal('835.20')), (10193, 'Shipped', Decimal('836.94')), (10193, 'Shipped', Decimal('839.52')), (10131, 'Shipped', Decimal('844.62')), (10346, 'Shipped', Decimal('848.54')), (10401, 'On Hold', Decimal('854.04')), (10303, 'Shipped', Decimal('856.80')), (10299, 'Shipped', Decimal('869.04')), (10391, 'Shipped', Decimal('870.96')), (10156, 'Shipped', Decimal('872.80')), (10262, 'Cancelled', Decimal('875.91')), (10391, 'Shipped', Decimal('876.15')), (10151, 'Shipped', Decimal('880.50')), (10324, 'Shipped', Decimal('880.50')), (10205, 'Shipped', Decimal('881.76')), (10371, 'Shipped', Decimal('887.40')), (10423, 'In Process', Decimal('891.50')), (10205, 'Shipped', Decimal('892.16')), (10193, 'Shipped', Decimal('896.00')), (10301, 'Shipped', Decimal('896.50')), (10202, 'Shipped', Decimal('901.53')), (10237, 'Shipped', Decimal('910.00')), (10425, 'In Process', Decimal('923.78')), (10173, 'Shipped', Decimal('925.97')), (10109, 'Shipped', Decimal('930.90')), (10288, 'Shipped', Decimal('933.51')), (10331, 'Shipped', Decimal('934.92')), (10185, 'Shipped', Decimal('937.20')), (10227, 'Shipped', Decimal('941.76')), (10332, 'Shipped', Decimal('945.80')), (10227, 'Shipped', Decimal('946.08')), (10138, 'Shipped', Decimal('951.78')), (10276, 'Shipped', Decimal('955.80')), (10380, 'Shipped', Decimal('955.84')), (10350, 'Shipped', Decimal('961.00')), (10206, 'Shipped', Decimal('961.38')), (10169, 'Shipped', Decimal('962.26')), (10412, 'Shipped', Decimal('966.34')), (10244, 'Shipped', Decimal('970.40')), (10347, 'Shipped', Decimal('973.56')), (10259, 'Shipped', Decimal('975.57')), (10296, 'Shipped', Decimal('980.28')), (10356, 'Shipped', Decimal('984.50')), (10412, 'Shipped', Decimal('986.40')), (10425, 'In Process', Decimal('986.42')), (10241, 'Shipped', Decimal('993.09')), (10220, 'Shipped', Decimal('994.20')), (10412, 'Shipped', Decimal('995.40')), (10192, 'Shipped', Decimal('996.90')), (10331, 'Shipped', Decimal('999.00')), (10312, 'Shipped', Decimal('999.58')), (10133, 'Shipped', Decimal('1001.43')), (10407, 'On Hold', Decimal('1001.65')), (10149, 'Shipped', Decimal('1002.82')), (10333, 'Shipped', Decimal('1014.24')), (10319, 'Shipped', Decimal('1015.00')), (10380, 'Shipped', Decimal('1016.01')), (10127, 'Shipped', Decimal('1017.20')), (10141, 'Shipped', Decimal('1017.20')), (10285, 'Shipped', Decimal('1017.60')), (10195, 'Shipped', Decimal('1018.24')), (10243, 'Shipped', Decimal('1018.71')), (10162, 'Shipped', Decimal('1019.35')), (10137, 'Shipped', Decimal('1046.50')), (10424, 'In Process', Decimal('1046.50')), (10122, 'Shipped', Decimal('1047.49')), (10139, 'Shipped', Decimal('1049.40')), (10268, 'Shipped', Decimal('1051.38')), (10173, 'Shipped', Decimal('1064.34')), (10416, 'Shipped', Decimal('1064.40')), (10374, 'Shipped', Decimal('1066.12')), (10296, 'Shipped', Decimal('1066.52')), (10289, 'Shipped', Decimal('1074.00')), (10403, 'Shipped', Decimal('1074.00')), (10415, 'Dispute ...

# %%
def pagos_agrupados_por_cliente_con_compra():

    cur = None

    data = None

    SQL = """SELECT DISTINCT p.customerNumber, p.checkNumber, p.paymentDate, p.amount FROM payments p 
LEFT JOIN sales s ON s.customerNumber=p.customerNumber WHERE s.customerNumber IS NOT NULL ORDER BY p.customerNumber"""
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        data = cur.fetchall()
    except Exception as err:
        print(f"Error: '{err}'")
    finally:
        if cur:
            cur.close()
        

    return data


resultado = pagos_agrupados_por_cliente_con_compra()
print(resultado)
# Out:
# SQL: SELECT DISTINCT p.customerNumber, p.checkNumber, p.paymentDate, p.amount FROM payments p
# LEFT JOIN sales s ON s.customerNumber=p.customerNumber WHERE s.customerNumber IS NOT NULL ORDER BY p.customerNumber
# [(103, 'HQ336336', datetime.date(2004, 10, 19), Decimal('6066.78')), (103, 'JM555205', datetime.date(2003, 6, 5), Decimal('14571.44')), (103, 'OM314933', datetime.date(2004, 12, 18), Decimal('1676.14')), (112, 'BO864823', datetime.date(2004, 12, 17), Decimal('14191.12')), (112, 'ND748579', datetime.date(2004, 8, 20), Decimal('33347.88')), (112, 'HQ55022', datetime.date(2003, 6, 6), Decimal('32641.98')), (114, 'NR27552', datetime.date(2004, 3, 10), Decimal('44894.74')), (114, 'NP603840', datetime.date(2003, 5, 31), Decimal('7565.08')), (114, 'MA765515', datetime.date(2004, 12, 15), Decimal('82261.22')), (114, 'GG31455', datetime.date(2003, 5, 20), Decimal('45864.03')), (119, 'LN373447', datetime.date(2004, 8, 8), Decimal('47924.19')), (119, 'DB933704', datetime.date(2004, 11, 14), Decimal('19501.82')), (119, 'NG94694', datetime.date(2005, 2, 22), Decimal('49523.67')), (121, 'MA302151', datetime.date(2004, 11, 28), Decimal('34638.14')), (121, 'FD317790', datetime.date(2003, 10, 28), Decimal('1491.38')), (121, 'DB889831', datetime.date(2003, 2, 16), Decimal('50218.95')), (121, 'KI831359', datetime.date(2004, 11, 4), Decimal('17876.32')), (124, 'HI366474', datetime.date(2004, 12, 27), Decimal('47142.70')), (124, 'HR86578', datetime.date(2004, 11, 2), Decimal('55639.66')), (124, 'CQ287967', datetime.date(2003, 4, 11), Decimal('11044.30')), (124, 'NT141748', datetime.date(2003, 11, 25), Decimal('45084.38')), (124, 'BG255406', datetime.date(2004, 8, 28), Decimal('85410.87')), (124, 'AE215433', datetime.date(2005, 3, 5), Decimal('101244.59')), (124, 'LF217299', datetime.date(2004, 3, 26), Decimal('43369.30')), (124, 'KI131716', datetime.date(2003, 8, 15), Decimal('111654.40')), (124, 'ET64396', datetime.date(2005, 4, 16), Decimal('83598.04')), (128, 'FH668230', datetime.date(2004, 3, 24), Decimal('33820.62')), (128, 'DI925118', datetime.date(2003, 1, 28), Decimal('10549.01')), (128, 'FA465482', datetime.date(2003, 10, 18), Decimal('24101.81')), (128, 'IP383901', datetime.date(2004, 11, 18), Decimal('7466.32')), (129, 'DM826140', datetime.date(2004, 12, 8), Decimal('26248.78')), (129, 'ID449593', datetime.date(2003, 12, 11), Decimal('23923.93')), (129, 'PI42991', datetime.date(2003, 4, 9), Decimal('16537.85')), (131, 'NB445135', datetime.date(2004, 9, 11), Decimal('35321.97')), (131, 'CL442705', datetime.date(2003, 3, 12), Decimal('22292.62')), (131, 'MA724562', datetime.date(2004, 12, 2), Decimal('50025.35')), (141, 'MC46946', datetime.date(2004, 7, 9), Decimal('35420.74')), (141, 'NU627706', datetime.date(2004, 5, 17), Decimal('26155.91')), (141, 'ID10962', datetime.date(2004, 12, 31), Decimal('116208.40')), (141, 'KT52578', datetime.date(2003, 12, 9), Decimal('63843.55')), (141, 'DL460618', datetime.date(2005, 5, 19), Decimal('46895.48')), (141, 'JN722010', datetime.date(2003, 2, 25), Decimal('40206.20')), (141, 'JN355280', datetime.date(2003, 10, 26), Decimal('49539.37')), (141, 'IN446258', datetime.date(2005, 3, 25), Decimal('65071.26')), (141, 'MF629602', datetime.date(2004, 8, 16), Decimal('20009.53')), (141, 'HJ32686', datetime.date(2004, 1, 30), Decimal('59830.55')), (141, 'JE105477', datetime.date(2005, 3, 18), Decimal('120166.58')), (141, 'DB583216', datetime.date(2004, 11, 1), Decimal('36140.38')), (141, 'AU364101', datetime.date(2003, 7, 19), Decimal('36251.03')), (144, 'IR846303', datetime.date(2004, 12, 12), Decimal('36005.71')), (144, 'LA685678', datetime.date(2003, 4, 9), Decimal('7674.94')), (145, 'CN328545', datetime.date(2004, 7, 3), Decimal('4710.73')), (145, 'JJ246391', datetime.date(2003, 2, 20), Decimal('53959.21')), (145, 'ED39322', datetime.date(2004, 4, 26), Decimal('28211.70')), (145, 'HR182688', datetime.date(2004, 12, 1), Decimal('20564.86')), (146, 'FP549817', datetime.date(2004, 3, 18), Decimal('40978.53')), (146, 'LJ160635', datetime.date(2003, 12, 10), Decimal('39712.10')), (146, 'FU793410', datetime.date(2004, 1, 16), Decimal('49614.72')), (151, 'IP568906', datetime.date(2003, 6, 18), Decimal('58841.3 ...

# %%
def ventas_productos_x_texto_cp(texto, cp):

    cur = None

    data = None

    SQL = """SELECT s.*, p.productName, c.postalCode FROM sales s 
LEFT JOIN products p ON (s.productCode = p.productCode) 
LEFT JOIN customers c ON s.customerNumber=c.customerNumber 
WHERE p.productName LIKE '%{0}%' AND c.postalCode = '{1}'""".format(texto, cp)
    print('SQL:', SQL)

    try:
        cur = conn.cursor()
        cur.execute(SQL)
        data = cur.fetchall()
    except Exception as err:
        print(f"Error: '{err}'")
    finally:
        if cur:
            cur.close()
        

    return data


resultado = ventas_productos_x_texto_cp('ar', 60528)
print(resultado)
# Out:
# SQL: SELECT s.*, p.productName, c.postalCode FROM sales s
# LEFT JOIN products p ON (s.productCode = p.productCode)
# LEFT JOIN customers c ON s.customerNumber=c.customerNumber
# WHERE p.productName LIKE '%ar%' AND c.postalCode = '60528'
# Error: 'connection already closed'
# None

# %%
# Cerramos conexión global
if conn: conn.close()
